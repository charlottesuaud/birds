# %%
import pandas as pd

# %%
df.head()
# Out:
#    Recording_ID  Genus Specific_epithet Subspecies English_name  \
# 0        356824  Sonus        naturalis        NaN   Soundscape
# 1        317951  Sonus        naturalis        NaN   Soundscape
# 2        508571  Sonus        naturalis        NaN   Soundscape
# 3        448534  Sonus        naturalis        NaN   Soundscape
# 4        373414  Sonus        naturalis        NaN   Soundscape
#
#            Recordist   Country                                    Locality  \
# 0  José Carlos Sires     Spain        doñana visitable, sevilla, andalucía
# 1  José Carlos Sires     Spain  arroyo algarbe, hinojos, huelva, andalucía
# 2   Nelson Conceição  Portugal                 Santo Estêvão, Tavira, Faro
# 3  José Carlos Sires     Spain                 Córdoba, Córdoba, Andalucía
# 4      Lars Lachmann   Germany         Frohnau, Berlin, north-eastern part
#
#    Latitude  Longitude                                  Vocalization_type  \
# ...

# %%
df[df[]]

# %%
import pandas as pd
pd.set_option('display.max_columns',500)

# %%
df = pd.read_csv("../raw_data/metadata.csv")
df
# Out:
#       Recording_ID       Genus Specific_epithet  Subspecies  \
# 0           356824       Sonus        naturalis         NaN
# 1           317951       Sonus        naturalis         NaN
# 2           508571       Sonus        naturalis         NaN
# 3           448534       Sonus        naturalis         NaN
# 4           373414       Sonus        naturalis         NaN
# ...            ...         ...              ...         ...
# 2145        518681  Glaucidium       passerinum         NaN
# 2146        401901  Glaucidium       passerinum  passerinum
# 2147        201176  Glaucidium       passerinum  passerinum
# 2148        408254  Glaucidium       passerinum         NaN
# 2149        309791  Glaucidium       passerinum         NaN
#
#             English_name          Recordist             Country  \
# 0             Soundscape  José Carlos Sires               Spain
# 1             Soundscape  José Carlos Sires               Spain
# ...

# %%
df

# %%
df['Species'].value_counts()
# Out:
# Sonus naturalis               43
# Locustella naevia             43
# Sylvia communis               43
# Aegolius funereus             43
# Cyanistes caeruleus           43
# Cuculus canorus               43
# Emberiza calandra             43
# Periparus ater                43
# Sylvia curruca                43
# Luscinia svecica              43
# Luscinia megarhynchos         43
# Hippolais icterina            43
# Alauda arvensis               43
# Ficedula parva                43
# Sylvia borin                  43
# Phylloscopus sibilatrix       43
# Turdus philomelos             43
# Athene noctua                 43
# Sylvia atricapilla            43
# Strix aluco                   43
# Pyrrhula pyrrhula             43
# Carduelis carduelis           43
# Phylloscopus collybita        43
# Carpodacus erythrinus         43
# Emberiza cirlus               43
# Crex crex                     43
# Oriolus oriolus               43
# Emberiza hortulana            43
# ...

# %%
sum(df['Species'].value_counts())
# Out:
# 2150

# %%
df['Other_species1'].value_counts()
# Out:
# Fringilla coelebs         75
# Turdus merula             57
# Parus major               25
# Alauda arvensis           25
# Erithacus rubecula        21
#                           ..
# Hippolais icterina         1
# Sturnus unicolor           1
# Merops apiaster            1
# Columba oenas              1
# Tachybaptus ruficollis     1
# Name: Other_species1, Length: 116, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
assert type(df) == pd.core.frame.DataFrame

# %%
assert type(df) == str
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-48-ef1a1a6add5d> in <module>
# ----> 1 assert type(df) == str
#
# AssertionError:

# %%
df['Other_species1'].notna()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2145     True
# 2146    False
# 2147    False
# 2148    False
# 2149    False
# Name: Other_species1, Length: 2150, dtype: bool

# %%
str = 'mp3//Fringilla-coelebs-168175.mp3'

# %%
str2 = str[5:]

# %%
str2
# Out:
# 'Fringilla-coelebs-168175.mp3'

# %%
df_alone = df[df['Other_species1'].isna()]
df_alone['Species'].value_counts()
# Out:
# Aegolius funereus             42
# Bubo bubo                     42
# Caprimulgus europaeus         42
# Athene noctua                 40
# Alauda arvensis               39
# Crex crex                     39
# Acrocephalus dumetorum        38
# Hirundo rustica               38
# Strix aluco                   38
# Acrocephalus palustris        38
# Carduelis carduelis           37
# Luscinia megarhynchos         36
# Periparus ater                36
# Emberiza schoeniclus          35
# Chloris chloris               34
# Locustella naevia             34
# Sylvia communis               33
# Sylvia atricapilla            33
# Parus major                   33
# Glaucidium passerinum         31
# Loxia curvirostra             31
# Emberiza citrinella           30
# Pyrrhula pyrrhula             30
# Sylvia borin                  30
# Linaria cannabina             30
# Fringilla coelebs             30
# Emberiza calandra             29
# Luscinia luscinia             29
# ...

# %%
df_alone['Species'].value_counts()
# Out:
# Aegolius funereus             42
# Bubo bubo                     42
# Caprimulgus europaeus         42
# Athene noctua                 40
# Alauda arvensis               39
# Crex crex                     39
# Acrocephalus dumetorum        38
# Hirundo rustica               38
# Strix aluco                   38
# Acrocephalus palustris        38
# Carduelis carduelis           37
# Luscinia megarhynchos         36
# Periparus ater                36
# Emberiza schoeniclus          35
# Chloris chloris               34
# Locustella naevia             34
# Sylvia communis               33
# Sylvia atricapilla            33
# Parus major                   33
# Glaucidium passerinum         31
# Loxia curvirostra             31
# Emberiza citrinella           30
# Pyrrhula pyrrhula             30
# Sylvia borin                  30
# Linaria cannabina             30
# Fringilla coelebs             30
# Emberiza calandra             29
# Luscinia luscinia             29
# ...

# %%
sum(df_alone['Species'].value_counts())
# Out:
# 1488

# %%
1488/2150
# Out:
# 0.6920930232558139

# %%
sum(df_alone['Species'].value_counts())
# Out:
# 662

# %%
df_alone3 = df[df['Other_species3'].notna()]
print(sum(df_alone3['Species'].value_counts()))
df_alone3['Species'].value_counts()
# Out:
# 433
# Sonus naturalis               41
# Phylloscopus sibilatrix       22
# Cuculus canorus               19
# Cyanistes caeruleus           18
# Phylloscopus collybita        17
# Oriolus oriolus               16
# Hippolais icterina            15
# Ficedula hypoleuca            14
# Phoenicurus phoenicurus       14
# Carpodacus erythrinus         14
# Turdus philomelos             13
# Troglodytes troglodytes       13
# Acrocephalus arundinaceus     13
# Emberiza cirlus               12
# Ficedula parva                11
# Emberiza hortulana            11
# Emberiza citrinella           11
# Turdus merula                 10
# Luscinia luscinia             10
# Acrocephalus schoenobaenus     9
# Erithacus rubecula             9
# Glaucidium passerinum          8
# Phylloscopus trochilus         8
# Pyrrhula pyrrhula              7
# Parus major                    7
# Linaria cannabina              7
# Sylvia borin                   7
# Locustella naevia              7
# ...

# %%
df['Other_species'].value_counts()
# Out:
# Fringilla coelebs          26
# Alauda arvensis            17
# Emberiza citrinella        16
# Turdus merula               9
# Phylloscopus trochilus      9
#                            ..
# Acrocephalus scirpaceus     1
# Certhia brachydactyla       1
# Anser anser                 1
# Anas platyrhynchos          1
# Ixobrychus minutus          1
# Name: Other_species, Length: 93, dtype: int64
